# %%
from auto_ml import Predictor
from auto_ml.utils import get_boston_dataset

df_train, df_test = get_boston_dataset()(         CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS   RAD    TAX  \
477  15.02340   0.0  18.10   0.0  0.6140  5.304  97.3  2.1007  24.0  666.0   
15    0.62739   0.0   8.14   0.0  0.5380  5.834  56.5  4.4986   4.0  307.0   
332   0.03466  35.0   6.06   0.0  0.4379  6.031  23.3  6.6407   1.0  304.0   
423   7.05042   0.0  18.10   0.0  0.6140  6.103  85.1  2.0218  24.0  666.0   
19    0.72580   0.0   8.14   0.0  0.5380  5.727  69.5  3.7965   

column_descriptions = {
    'MEDV': 'output'
    , 'CHAS': 'categorical'
}

ml_predictor = Predictor(type_of_estimator='regressor', column_descriptions=column_descriptions)

ml_predictor.train(df_train)

ml_predictor.score(df_test, df_test.MEDV)
# Out:
# /home/lucas/anaconda3/lib/python3.7/site-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# Welcome to auto_ml! We're about to go through and make sense of your data using machine learning, and give you a production-ready pipeline to get predictions with.
#
# If you have any issues, or new feature ideas, let us know at http://auto.ml
# You are running on version 2.9.10
# Now using the model training_params that you passed in:
# {}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'presort': False, 'learning_rate': 0.1, 'warm_start': True}
# Running basic data cleaning
# Fitting DataFrameVectorizer
# Now using the model training_params that you passed in:
# {}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'presort': False, 'learning_rate': 0.1, 'warm_start': True}
#
#
# ********************************************************************************************
# About to fit the pipeline for the model GradientBoostingRegressor to predict MEDV
# Started at:
# 2020-01-23 20:30:51
# [1] random_holdout_set_from_training_data's score is: -8.361
# [2] random_holdout_set_from_training_data's score is: -7.762
# [3] random_holdout_set_from_training_data's score is: -7.324
# [4] random_holdout_set_from_training_data's score is: -6.798
# [5] random_holdout_set_from_training_data's score is: -6.358
# [6] random_holdout_set_from_training_data's score is: -5.975
# [7] random_holdout_set_from_training_data's score is: -5.683
# [8] random_holdout_set_from_training_data's score is: -5.338
# [9] random_holdout_set_from_training_data's score is: -5.019
# [10] random_holdout_set_from_training_data's score is: -4.819
# [11] random_holdout_set_from_training_data's score is: -4.534
# [12] random_holdout_set_from_training_data's score is: -4.401
# [13] random_holdout_set_from_training_data's score is: -4.203
# [14] random_holdout_set_from_training_data's score is: -4.018
# [15] random_holdout_set_from_training_data's score is: -3.867
# [16] random_holdout_set_from_training_data's score is: -3.78
# [17] random_holdout_set_from_training_data's score is: -3.663
# [18] random_holdout_set_from_training_data's score is: -3.588
# [19] random_holdout_set_from_training_data's score is: -3.499
# [20] random_holdout_set_from_training_data's score is: -3.423
# [21] random_holdout_set_from_training_data's score is: -3.355
# [22] random_holdout_set_from_training_data's score is: -3.316
# [23] random_holdout_set_from_training_data's score is: -3.263
# [24] random_holdout_set_from_training_data's score is: -3.235
# [25] random_holdout_set_from_training_data's score is: -3.216
# [26] random_holdout_set_from_training_data's score is: -3.169
# [27] random_holdout_set_from_training_data's score is: -3.139
# [28] random_holdout_set_from_training_data's score is: -3.097
# [29] random_holdout_set_from_training_data's score is: -3.054
# [30] random_holdout_set_from_training_data's score is: -3.03
# [31] random_holdout_set_from_training_data's score is: -3.0
# [32] random_holdout_set_from_training_data's score is: -2.973
# [33] random_holdout_set_from_training_data's score is: -2.966
# [34] random_holdout_set_from_training_data's score is: -2.956
# [35] random_holdout_set_from_training_data's score is: -2.92
# [36] random_holdout_set_from_training_data's score is: -2.897
# [37] random_holdout_set_from_training_data's score is: -2.877
# [38] random_holdout_set_from_training_data's score is: -2.863
# [39] random_holdout_set_from_training_data's score is: -2.853
# [40] random_holdout_set_from_training_data's score is: -2.847
# [41] random_holdout_set_from_training_data's score is: -2.844
# [42] random_holdout_set_from_training_data's score is: -2.857
# [43] random_holdout_set_from_training_data's score is: -2.852
# [44] random_holdout_set_from_training_data's score is: -2.845
# [45] random_holdout_set_from_training_data's score is: -2.838
# [46] random_holdout_set_from_training_data's score is: -2.818
# [47] random_holdout_set_from_training_data's score is: -2.815
# [48] random_holdout_set_from_training_data's score is: -2.815
# [49] random_holdout_set_from_training_data's score is: -2.801
# [50] random_holdout_set_from_training_data's score is: -2.798
# [52] random_holdout_set_from_training_data's score is: -2.788
# [54] random_holdout_set_from_training_data's score is: -2.785
# [56] random_holdout_set_from_training_data's score is: -2.789
# [58] random_holdout_set_from_training_data's score is: -2.777
# [60] random_holdout_set_from_training_data's score is: -2.774
# [62] random_holdout_set_from_training_data's score is: -2.767
# [64] random_holdout_set_from_training_data's score is: -2.774
# [66] random_holdout_set_from_training_data's score is: -2.769
# [68] random_holdout_set_from_training_data's score is: -2.77
# [70] random_holdout_set_from_training_data's score is: -2.783
# [72] random_holdout_set_from_training_data's score is: -2.782
# [74] random_holdout_set_from_training_data's score is: -2.783
# [76] random_holdout_set_from_training_data's score is: -2.762
# [78] random_holdout_set_from_training_data's score is: -2.764
# [80] random_holdout_set_from_training_data's score is: -2.771
# [82] random_holdout_set_from_training_data's score is: -2.773
# [84] random_holdout_set_from_training_data's score is: -2.778
# [86] random_holdout_set_from_training_data's score is: -2.775
# [88] random_holdout_set_from_training_data's score is: -2.779
# [90] random_holdout_set_from_training_data's score is: -2.782
# [92] random_holdout_set_from_training_data's score is: -2.782
# [94] random_holdout_set_from_training_data's score is: -2.781
# [96] random_holdout_set_from_training_data's score is: -2.775
# [98] random_holdout_set_from_training_data's score is: -2.78
# [100] random_holdout_set_from_training_data's score is: -2.759
# [103] random_holdout_set_from_training_data's score is: -2.77
# [106] random_holdout_set_from_training_data's score is: -2.768
# [109] random_holdout_set_from_training_data's score is: -2.767
# [112] random_holdout_set_from_training_data's score is: -2.773
# [115] random_holdout_set_from_training_data's score is: -2.77
# [118] random_holdout_set_from_training_data's score is: -2.782
# [121] random_holdout_set_from_training_data's score is: -2.792
# [124] random_holdout_set_from_training_data's score is: -2.786
# [127] random_holdout_set_from_training_data's score is: -2.791
# [130] random_holdout_set_from_training_data's score is: -2.791
# [133] random_holdout_set_from_training_data's score is: -2.798
# [136] random_holdout_set_from_training_data's score is: -2.788
# [139] random_holdout_set_from_training_data's score is: -2.794
# [142] random_holdout_set_from_training_data's score is: -2.791
# [145] random_holdout_set_from_training_data's score is: -2.782
# [148] random_holdout_set_from_training_data's score is: -2.781
# [151] random_holdout_set_from_training_data's score is: -2.777
# [154] random_holdout_set_from_training_data's score is: -2.78
# [157] random_holdout_set_from_training_data's score is: -2.779
# [160] random_holdout_set_from_training_data's score is: -2.782
# The number of estimators that were the best for this training dataset: 100
# The best score on the holdout set: -2.7589248179306174
# Finished training the pipeline!
# Total training time:
# 0:00:01
#
#
# Here are the results from our GradientBoostingRegressor
# predicting MEDV
# Calculating feature responses, for advanced analytics.
# The printed list will only contain at most the top 100 features.
# +----+----------------+--------------+----------+-------------------+-------------------+-----------+-----------+-----------+-----------+
# |    | Feature Name   |   Importance |    Delta |   FR_Decrementing |   FR_Incrementing |   FRD_abs |   FRI_abs |   FRD_MAD |   FRI_MAD |
# |----+----------------+--------------+----------+-------------------+-------------------+-----------+-----------+-----------+-----------|
# | 12 | CHAS=0.0       |       0.0002 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 13 | CHAS=1.0       |       0.0003 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# |  1 | ZN             |       0.0006 |  11.5619 |           -0.0243 |            0.0248 |    0.0263 |    0.0376 |    0.0000 |    0.0000 |
# |  7 | RAD            |       0.0017 |   4.2895 |           -0.2427 |            0.0668 |    0.2456 |    0.0764 |    0.2068 |    0.0000 |
# |  2 | INDUS          |       0.0021 |   3.4430 |            0.0880 |            0.0983 |    0.1358 |    0.1825 |    0.0577 |    0.0000 |
# |  8 | TAX            |       0.0107 |  82.9834 |            1.1674 |           -0.2608 |    1.2172 |    0.2937 |    0.0708 |    0.0306 |
# | 10 | B              |       0.0123 |  45.7266 |           -0.1497 |            0.0898 |    0.2076 |    0.1592 |    0.0000 |    0.0000 |
# |  5 | AGE            |       0.0193 |  13.9801 |            0.2078 |           -0.1804 |    0.4824 |    0.3417 |    0.3544 |    0.1618 |
# |  0 | CRIM           |       0.0218 |   4.4320 |           -0.4456 |           -0.4623 |    0.6500 |    0.5574 |    0.6277 |    0.4489 |
# |  9 | PTRATIO        |       0.0302 |   1.1130 |            0.6066 |           -0.3485 |    0.6430 |    0.3834 |    0.4602 |    0.1472 |
# |  3 | NOX            |       0.0326 |   0.0588 |            0.1087 |           -0.2228 |    0.2604 |    0.3383 |    0.0561 |    0.0000 |
# |  6 | DIS            |       0.0666 |   1.0643 |            3.4216 |           -0.2935 |    3.5103 |    0.6461 |    0.7824 |    0.2944 |
# | 11 | LSTAT          |       0.3882 |   3.5508 |            1.8219 |           -1.7771 |    1.8463 |    1.8029 |    1.5141 |    1.3589 |
# |  4 | RM             |       0.4135 |   0.3543 |           -1.1502 |            1.4879 |    1.2657 |    1.6871 |    0.5645 |    0.7157 |
# +----+----------------+--------------+----------+-------------------+-------------------+-----------+-----------+-----------+-----------+
#
#
# *******
# Legend:
# Importance = Feature Importance
#      Explanation: A weighted measure of how much of the variance the model is able to explain is due to this column
# FR_delta = Feature Response Delta Amount
#      Explanation: Amount this column was incremented or decremented by to calculate the feature reponses
# FR_Decrementing = Feature Response From Decrementing Values In This Column By One FR_delta
#      Explanation: Represents how much the predicted output values respond to subtracting one FR_delta amount from every value in this column
# FR_Incrementing = Feature Response From Incrementing Values In This Column By One FR_delta
#      Explanation: Represents how much the predicted output values respond to adding one FR_delta amount to every value in this column
# FRD_MAD = Feature Response From Decrementing- Median Absolute Delta
#      Explanation: Takes the absolute value of all changes in predictions, then takes the median of those. Useful for seeing if decrementing this feature provokes strong changes that are both positive and negative
# FRI_MAD = Feature Response From Incrementing- Median Absolute Delta
#      Explanation: Takes the absolute value of all changes in predictions, then takes the median of those. Useful for seeing if incrementing this feature provokes strong changes that are both positive and negative
# FRD_abs = Feature Response From Decrementing Avg Absolute Change
#      Explanation: What is the average absolute change in predicted output values to subtracting one FR_delta amount to every value in this column. Useful for seeing if output is sensitive to a feature, but not in a uniformly positive or negative way
# FRI_abs = Feature Response From Incrementing Avg Absolute Change
#      Explanation: What is the average absolute change in predicted output values to adding one FR_delta amount to every value in this column. Useful for seeing if output is sensitive to a feature, but not in a uniformly positive or negative way
# *******
# None
#
#
# ***********************************************
# Advanced scoring metrics for the trained regression model on this particular dataset:
#
# Here is the overall RMSE for these predictions:
# 2.6655438635543853
#
# Here is the average of the predictions:
# 21.17083526222861
#
# Here is the average actual value on this validation set:
# 21.488235294117654
#
# Here is the median prediction:
# 20.578693322051983
#
# Here is the median actual value:
# 20.15
#
# Here is the mean absolute error:
# 1.9879425214755084
#
# Here is the median absolute error (robust to outliers):
# 1.4284775565386862
#
# Here is the explained variance:
# 0.9044862953139041
#
# Here is the R-squared value:
# 0.9031125385554001
# Count of positive differences (prediction > actual):
# 50
# Count of negative differences:
# 52
# Average positive difference:
# 1.7039533393781972
# Average negative difference:
# -2.261009042722923
#
#
# ***********************************************
# -2.6655438635543853

# %%
print(get_boston_dataset())
# Out:
# (         CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS   RAD    TAX  \
# 477  15.02340   0.0  18.10   0.0  0.6140  5.304  97.3  2.1007  24.0  666.0
# 15    0.62739   0.0   8.14   0.0  0.5380  5.834  56.5  4.4986   4.0  307.0
# 332   0.03466  35.0   6.06   0.0  0.4379  6.031  23.3  6.6407   1.0  304.0
# 423   7.05042   0.0  18.10   0.0  0.6140  6.103  85.1  2.0218  24.0  666.0
# 19    0.72580   0.0   8.14   0.0  0.5380  5.727  69.5  3.7965   4.0  307.0
# ..        ...   ...    ...   ...     ...    ...   ...     ...   ...    ...
# 106   0.17120   0.0   8.56   0.0  0.5200  5.836  91.9  2.2110   5.0  384.0
# 270   0.29916  20.0   6.96   0.0  0.4640  5.856  42.1  4.4290   3.0  223.0
# 348   0.01501  80.0   2.01   0.0  0.4350  6.635  29.7  8.3440   4.0  280.0
# 435  11.16040   0.0  18.10   0.0  0.7400  6.629  94.6  2.1247  24.0  666.0
# 102   0.22876   0.0   8.56   0.0  0.5200  6.405  85.4  2.7147   5.0  384.0
#
#      PTRATIO       B  LSTAT  MEDV
# 477     20.2  349.48  24.91  12.0
# 15      21.0  395.62   8.47  19.9
# 332     16.9  362.25   7.83  19.4
# 423     20.2    2.52  23.29  13.4
# 19      21.0  390.95  11.28  18.2
# ..       ...     ...    ...   ...
# 106     20.9  395.67  18.66  19.5
# 270     18.6  388.65  13.00  21.1
# 348     17.0  390.94   5.99  24.5
# 435     20.2  109.85  23.27  13.4
# 102     20.9   70.80  10.63  18.6
#
# [404 rows x 14 columns],          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 173   0.09178   0.0   4.05   0.0  0.510  6.416   84.1  2.6463   5.0  296.0
# 274   0.05644  40.0   6.41   1.0  0.447  6.758   32.9  4.0776   4.0  254.0
# 491   0.10574   0.0  27.74   0.0  0.609  5.983   98.8  1.8681   4.0  711.0
# 72    0.09164   0.0  10.81   0.0  0.413  6.065    7.8  5.2873   4.0  305.0
# 452   5.09017   0.0  18.10   0.0  0.713  6.297   91.8  2.3682  24.0  666.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 412  18.81100   0.0  18.10   0.0  0.597  4.628  100.0  1.5539  24.0  666.0
# 436  14.42080   0.0  18.10   0.0  0.740  6.461   93.3  2.0026  24.0  666.0
# 411  14.05070   0.0  18.10   0.0  0.597  6.657  100.0  1.5275  24.0  666.0
# 86    0.05188   0.0   4.49   0.0  0.449  6.015   45.1  4.4272   3.0  247.0
# 75    0.09512   0.0  12.83   0.0  0.437  6.286   45.0  4.5026   5.0  398.0
#
#      PTRATIO       B  LSTAT  MEDV
# 173     16.6  395.50   9.04  23.6
# 274     17.6  396.90   3.53  32.4
# 491     20.1  390.11  18.07  13.6
# 72      19.2  390.91   5.52  22.8
# 452     20.2  385.09  17.27  16.1
# ..       ...     ...    ...   ...
# 412     20.2   28.79  34.37  17.9
# 436     20.2   27.49  18.05   9.6
# 411     20.2   35.05  21.22  17.2
# 86      18.5  395.99  12.86  22.5
# 75      18.7  383.23   8.94  21.4
#
# [102 rows x 14 columns])
